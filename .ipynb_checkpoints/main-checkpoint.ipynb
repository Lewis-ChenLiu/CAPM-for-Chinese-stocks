# %% [markdown]
# More about data on https://waditu.com/document/2?doc_id=14

# %%
# Load the data scraping package, token needded
import tushare as ts
import pandas as pd
import re

ts.set_token('b3b047bac87545ebc16e28f9c59287f79b0955a5e95970371a45db29')
pro = ts.pro_api()

# %%
# stock basic information
stock_basic = pro.stock_basic(list_status='L', fields='ts_code,name,area,industry')
# stock company information
stock_company = pro.stock_company(fields='ts_code,reg_capital,setup_date,main_business,business_scope')

stock = pd.merge(stock_basic,stock_company)
stock['setup_date'] = pd.to_datetime(stock['setup_date'])

# %%
stock
# Out:
#         ts_code    name area industry   reg_capital setup_date  \
# 0     000001.SZ    平安银行   深圳       银行  1.940592e+06 1987-12-22
# 1     000002.SZ     万科A   深圳     全国地产  1.161773e+06 1984-05-30
# 2     000004.SZ    国农科技   深圳      互联网  1.650526e+04 1986-05-05
# 3     000005.SZ    世纪星源   深圳     环境保护  1.058537e+05 1989-05-08
# 4     000006.SZ    深振业A   深圳     区域地产  1.349995e+05 1989-05-25
# ...         ...     ...  ...      ...           ...        ...
# 4059  688598.SH    金博股份   湖南     矿物制品  8.000000e+03 2005-06-06
# 4060  688599.SH    天合光能   江苏     电气设备  2.068026e+05 1997-12-26
# 4061  688600.SH    皖仪科技   安徽     电器仪表  1.333400e+04 2003-06-26
# 4062  688788.SH    科思科技   深圳     通信设备  7.553423e+03 2004-02-27
# 4063  688981.SH  中芯国际-U   上海      半导体  7.698462e+05 2000-04-03
#
#                                          business_scope  \
# 0     (一)吸收公众存款；(二)发放短期、中期和长期贷款；(三)办理国内外结算；(四)办理票据承兑...
# 1     房地产开发；兴办实业(具体项目另行申报)；国内商业、物资供销业(不含专营、专控、专卖商品)；...
# ...

# %%
pro.query('daily', ts_code='000001.SZ', start_date='20180701', end_date='20180718')
# Out:
#       ts_code trade_date  open  high   low  close  pre_close  change  pct_chg  \
# 0   000001.SZ   20180718  8.75  8.85  8.69   8.70       8.72   -0.02    -0.23
# 1   000001.SZ   20180717  8.74  8.75  8.66   8.72       8.73   -0.01    -0.11
# 2   000001.SZ   20180716  8.85  8.90  8.69   8.73       8.88   -0.15    -1.69
# 3   000001.SZ   20180713  8.92  8.94  8.82   8.88       8.88    0.00     0.00
# 4   000001.SZ   20180712  8.60  8.97  8.58   8.88       8.64    0.24     2.78
# 5   000001.SZ   20180711  8.76  8.83  8.68   8.78       8.98   -0.20    -2.23
# 6   000001.SZ   20180710  9.02  9.02  8.89   8.98       9.03   -0.05    -0.55
# 7   000001.SZ   20180709  8.69  9.03  8.68   9.03       8.66    0.37     4.27
# 8   000001.SZ   20180706  8.61  8.78  8.45   8.66       8.60    0.06     0.70
# 9   000001.SZ   20180705  8.62  8.73  8.55   8.60       8.61   -0.01    -0.12
# 10  000001.SZ   20180704  8.63  8.75  8.61   8.61       8.67   -0.06    -0.69
# ...

# %%
stock_list
# Out:
#         ts_code  symbol    name area industry         fullname
# 0     000001.SZ  000001    平安银行   深圳       银行       平安银行股份有限公司
# 1     000002.SZ  000002     万科A   深圳     全国地产       万科企业股份有限公司
# 2     000004.SZ  000004    国农科技   深圳      互联网   深圳国华网安科技股份有限公司
# 3     000005.SZ  000005    世纪星源   深圳     环境保护     深圳世纪星源股份有限公司
# 4     000006.SZ  000006    深振业A   深圳     区域地产  深圳市振业(集团)股份有限公司
# ...         ...     ...     ...  ...      ...              ...
# 4067  688599.SH  688599    天合光能   江苏     电气设备       天合光能股份有限公司
# 4068  688600.SH  688600    皖仪科技   安徽     电器仪表     安徽皖仪科技股份有限公司
# 4069  688777.SH  688777    中控技术   浙江     软件服务     浙江中控技术股份有限公司
# 4070  688788.SH  688788    科思科技   深圳     通信设备    深圳市科思科技股份有限公司
# 4071  688981.SH  688981  中芯国际-U   上海      半导体   中芯国际集成电路制造有限公司
#
# [4072 rows x 6 columns]

# %%
http://stock.10jqka.com.cn/tzjh_list/20201130/
# Out:
#                                                 title  \
# 0                     旺能环境：中标2.5亿元蚌埠市餐厨废弃物及污泥处理特许经营项目
# 1                            博信股份：拟6900万元出售博成市政100%股权
# 2                                      盒马鲜生“标签门”侵犯了谁？
# 3                                   经济性不佳或致美多座核电站提前关停
# 4                                江森自控：新时代智慧医院白皮书（附下载）
# 5                    Gartner L2：只有13%的企业能提供具有高度针对性的消息
# 6                              懂车帝：2018汽车行业大数据报告（附下载）
# 7                                     争议五星酒店“2000元”罚单
# 8                                    李超：加快推动资本市场数字化转型
# 9                                    财险市场变革“冲击”传统估值模型
# 10                                  A股是重要投资方向主要关注两个领域
# 11                              三季度网贷交易量普跌拍拍贷、乐信抗跌能力强
# 12                                机构升级智能交易 一键超额快赎货币基金
# 13                                发行股份重组停牌时间不超过10个交易日
# 14                                         深沪证券市场每日行情
# 15             关于新华恒稳添利债券型证券投资基金增加A类份额并修改基金合同和托管协议的公告
# ...
